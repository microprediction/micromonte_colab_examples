# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/micromonte_colab_examples/blob/main/implied_weekly_volatilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade monteprediction
# Out:
# ...
#   Attempting uninstall: monteprediction
#     Found existing installation: monteprediction 1.0.10
#     Uninstalling monteprediction-1.0.10:
#       Successfully uninstalled monteprediction-1.0.10
# ...

# %%
from monteprediction.optionsutil import get_weekly_options, get_weekly_implied
df = get_weekly_options()
df[:5]
# Out:
#   ticker              retrievalTime  callStrike  callPrice  originalCallIV  \
# 0    XLB 2024-05-11 15:43:02.522623        92.0       0.60        0.202401
# 1    XLC 2024-05-11 15:43:02.821015        81.5       0.92        0.988281
# 2    XLE 2024-05-11 15:43:03.192387        94.0       0.78        0.154549
# 3    XLF 2024-05-11 15:43:03.517350        42.0       0.25        0.137216
# 4    XLI 2024-05-11 15:43:03.860868       125.5       1.01        0.147958
#
#    adjustedCallIV  putStrike  putPrice  originalPutIV  adjustedPutIV  \
# 0        0.022722       92.0      0.65       0.161141       0.018090
# 1        0.110946       81.5      0.51       0.386237       0.043360
# 2        0.017350       94.0      0.79       0.154794       0.017377
# 3        0.015404       42.0      0.33       0.203133       0.022804
# 4        0.016610      125.5      0.67       0.344245       0.038646
#
#    impliedStd
# 0    0.020406
# 1    0.077153
# 2    0.017364
# 3    0.019104
# 4    0.027628

# %%
print(get_weekly_implied())
# Out:
# {'XLB': 0.020405948574222413, 'XLC': 0.0771530165927283, 'XLE': 0.017363724691076242, 'XLF': 0.019104096011614818, 'XLI': 0.027627804368898244, 'XLK': 0.019830392704438003, 'XLP': 0.011594462282046782, 'XLRE': 0.06682070038417603, 'XLU': 0.02091298588808011, 'XLV': 0.013800759782887024, 'XLY': 0.019624837036657856}
